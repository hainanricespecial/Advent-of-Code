# %%
# Read the file.
inputfile = open("part1input.txt").readline()

splittedfile = inputfile.strip().split(",")

finalsplittedfile = []

total = 0

# For every line in the range list, we split it by the minus sign.

for item in splittedfile:

    currentrangesplitted = item.split("-")
    finalsplittedfile.append(currentrangesplitted)


for id in finalsplittedfile:

    print(id[0])
    print(id[1])

    for x in range(int(id[0]), int(id[1])):
        stringcompare = str(x)
# Out:
# 17330
# 35281
# 9967849351
# 9967954114
# 880610
# 895941
# 942
# 1466
# 117855
# 209809
# 9427633930
# 9427769294
# 1
# 14
# 311209
# 533855
# 53851
# 100089
# 104
# 215
# 33317911
# 33385573
# 42384572
# 42481566
# 43
# 81
# 87864705
# 87898981
# 258952
# 303177
# 451399530
# 451565394
# 6464564339
# 6464748782
# 1493
# 2439
# 9941196
# 10054232
# 2994
# 8275
# 6275169
# 6423883
# 20
# 41
# 384
# 896
# 2525238272
# 2525279908
# 8884
# 16221
# 968909030
# 969019005
# 686256
# 831649
# 942986
# 986697
# 1437387916
# 1437426347
# 8897636
# 9031809
# 16048379
# 16225280
